# %%
import pandas as pd

# %%
ri = pd.read_csv('police.csv')

# %%
ri.head(3)
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
#
#    driver_age driver_race violation_raw violation  search_conducted  \
# 0        20.0       White      Speeding  Speeding             False
# 1        40.0       White      Speeding  Speeding             False
# 2        33.0       White      Speeding  Speeding             False
#
#   search_type stop_outcome is_arrested stop_duration  drugs_related_stop
# 0         NaN     Citation       False      0-15 Min               False
# 1         NaN     Citation       False      0-15 Min               False
# 2         NaN     Citation       False      0-15 Min               False

# %%
ri.columns
# Out:
# Index(['stop_date', 'stop_time', 'county_name', 'driver_gender',
#        'driver_age_raw', 'driver_age', 'driver_race', 'violation_raw',
#        'violation', 'search_conducted', 'search_type', 'stop_outcome',
#        'is_arrested', 'stop_duration', 'drugs_related_stop'],
#       dtype='object')

# %%
#locating missing values

# %%
ri.isnull()
# Out:
#        stop_date  stop_time  county_name  driver_gender  driver_age_raw  \
# 0          False      False         True          False           False
# 1          False      False         True          False           False
# 2          False      False         True          False           False
# 3          False      False         True          False           False
# 4          False      False         True          False           False
# 5          False      False         True          False           False
# 6          False      False         True          False           False
# 7          False      False         True          False           False
# 8          False      False         True          False           False
# 9          False      False         True          False           False
# 10         False      False         True          False           False
# 11         False      False         True          False           False
# ...

# %%
ri.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# county_name           91741
# driver_gender          5335
# driver_age_raw         5327
# driver_age             5621
# driver_race            5333
# violation_raw          5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# drugs_related_stop        0
# dtype: int64

# %%
#Dropping rows
#.dropna()

# %%
# Import the pandas library as pd
import pandas as pd

# Read 'police.csv' into a DataFrame named ri
ri = pd.read_csv('police.csv')

# Examine the head of the DataFrame
print(ri.head())
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
# 3  2005-02-20     17:15          NaN             M          1986.0
# 4  2005-03-14     10:00          NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %%
# Count the number of missing values in each column
print(ri.isnull().sum())
# Out:
# stop_date                 0
# stop_time                 0
# county_name           91741
# driver_gender          5335
# driver_age_raw         5327
# driver_age             5621
# driver_race            5333
# violation_raw          5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# drugs_related_stop        0
# dtype: int64

# %%
ri.columns

# %%
# Examine the shape of the DataFrame
print("Shape of DataFrame before Dropping",ri.shape)

# Drop the 'county_name' and 'state' columns
ri.drop(['county_name', 'driver_gender'], axis="columns", inplace=True)

# Examine the shape of the DataFrame (again)
print("Shape of DataFrame after Dropping",ri.shape)
# Out:
# Shape of DataFrame before Dropping (91741, 15)
# Shape of DataFrame after Dropping (91741, 13)

# %%
# Count the number of missing values in each column
print(ri.isnull().sum())
# Out:
# stop_date                 0
# stop_time                 0
# driver_age_raw         5327
# driver_age             5621
# driver_race            5333
# violation_raw          5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# drugs_related_stop        0
# dtype: int64

# %%
ri=pd.read_csv("police.csv")
# Count the number of missing values in each column
print(ri.isnull().sum())

# Drop all rows that are missing 'driver_gender'
ri.dropna(subset=['driver_gender'], inplace=True)

# Count the number of missing values in each column (again)
print(ri.isnull().sum())

# Examine the shape of the DataFrame
print(ri.shape)
# Out:
# stop_date                 0
# stop_time                 0
# county_name           91741
# driver_gender          5335
# driver_age_raw         5327
# driver_age             5621
# driver_race            5333
# violation_raw          5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# drugs_related_stop        0
# dtype: int64
# stop_date                 0
# stop_time                 0
# county_name           86406
# driver_gender             0
# driver_age_raw            1
# driver_age              293
# driver_race               0
# violation_raw             0
# violation                 0
# search_conducted          0
# search_type           83210
# stop_outcome              0
# is_arrested               0
# stop_duration             0
# drugs_related_stop        0
# dtype: int64
# (86406, 15)

# %%
#Examining the data types
#Object: Python strings  (or Other Python Objects)
#bool : True and false values

# %%
# Why do datatypes matters:
#Affects whcih operations you perform
#Avoid strong data as strings
    #int,floa: Enables matheatical operations
    #datetime: enables date based attriibutes and methods
    #category: uses less memory and runs faster
    #bool: enables logical and mathematical operations

# %%
#Fixing a data type
#apple
#apple.price.dtype
#apple['price'] = apple.price.astype('float')

#while assigning something, left side always use [], then code will be more clear

# %%
# Examine the head of the 'is_arrested' column
print(ri.is_arrested.dtype)
# Out:
# object

# %%
ri.dtypes
# Out:
# stop_date              object
# stop_time              object
# county_name           float64
# driver_gender          object
# driver_age_raw        float64
# driver_age            float64
# driver_race            object
# violation_raw          object
# violation              object
# search_conducted         bool
# search_type            object
# stop_outcome           object
# is_arrested            object
# stop_duration          object
# drugs_related_stop       bool
# dtype: object

# %%
# Change the data type of 'is_arrested' to 'bool'
ri['is_arrested'] = ri.is_arrested.astype('bool')

# Check the data type of 'is_arrested' 
print(ri.is_arrested.dtype)
# Out:
# bool

# %% [raw]
# Creating a date time index
# 1. combine 'stop_date' and 'stop_time' into one column
# 2. convert it to datetime column
# apple
# apple.date.str.replace('/', '-')
# Combined = apple.date.str.cat(apple.time, sep =' ')
# apple['date_and_time'] = pd.to_datetime(combined)
# apple.dtypes
# #Now datatype of 'date_and_time' will be datetime64[ns]- that means it converted to datetime format
#
# #Settins Index:
# apple.set_index('date_and_time', inplace = True)
# apple.index

# %%
# Concatenate 'stop_date' and 'stop_time' (separated by a space)
combined = ri.stop_date.str.cat(ri.stop_time, sep= " ")

# Convert 'combined' to datetime format
ri['stop_datetime'] = pd.to_datetime(combined)

# Examine the data types of the DataFrame
print(ri.stop_datetime.dtype)
# Out:
# datetime64[ns]

# %%
# Concatenate 'stop_date' and 'stop_time' (separated by a space)
combined = ri.stop_date.str.cat(ri.stop_time, sep= " ")

# Convert 'combined' to datetime format
ri['stop_datetime'] = pd.to_datetime(combined)

# Examine the data types of the DataFrame
print(ri.dtypes)
# Out:
# stop_date                     object
# stop_time                     object
# county_name                  float64
# driver_gender                 object
# driver_age_raw               float64
# driver_age                   float64
# driver_race                   object
# violation_raw                 object
# violation                     object
# search_conducted                bool
# search_type                   object
# stop_outcome                  object
# is_arrested                     bool
# stop_duration                 object
# drugs_related_stop              bool
# stop_datetime         datetime64[ns]
# dtype: object

# %%
# Set 'stop_datetime' as the index
ri.set_index('stop_datetime', inplace=True)

# Examine the index
print(ri.index)

# Examine the columns
print(ri.columns)
# Out:
# DatetimeIndex(['2005-01-02 01:55:00', '2005-01-18 08:15:00',
#                '2005-01-23 23:15:00', '2005-02-20 17:15:00',
#                '2005-03-14 10:00:00', '2005-03-23 09:45:00',
#                '2005-04-01 17:30:00', '2005-06-06 13:20:00',
#                '2005-07-13 10:15:00', '2005-07-13 15:45:00',
#                ...
#                '2015-12-31 16:38:00', '2015-12-31 19:44:00',
#                '2015-12-31 19:55:00', '2015-12-31 20:20:00',
#                '2015-12-31 20:25:00', '2015-12-31 20:27:00',
#                '2015-12-31 20:35:00', '2015-12-31 20:45:00',
#                '2015-12-31 21:42:00', '2015-12-31 22:46:00'],
#               dtype='datetime64[ns]', name='stop_datetime', length=86406, freq=None)
# Index(['stop_date', 'stop_time', 'county_name', 'driver_gender',
#        'driver_age_raw', 'driver_age', 'driver_race', 'violation_raw',
#        'violation', 'search_conducted', 'search_type', 'stop_outcome',
# ...

# %%
#Counting Unique values
# .value_counts()  : Counts the unique values in a series
#Best suited for categorical data
ri.stop_outcome.value_counts()
# Out:
# Citation            77005
# Warning              5293
# Arrest Driver        2571
# N/D                   590
# No Action             589
# Arrest Passenger      358
# Name: stop_outcome, dtype: int64

# %%
ri.head()
# Out:
#                       stop_date stop_time  county_name driver_gender  \
# stop_datetime
# 2005-01-02 01:55:00  2005-01-02     01:55          NaN             M
# 2005-01-18 08:15:00  2005-01-18     08:15          NaN             M
# 2005-01-23 23:15:00  2005-01-23     23:15          NaN             M
# 2005-02-20 17:15:00  2005-02-20     17:15          NaN             M
# 2005-03-14 10:00:00  2005-03-14     10:00          NaN             F
#
#                      driver_age_raw  driver_age driver_race     violation_raw  \
# stop_datetime
# 2005-01-02 01:55:00          1985.0        20.0       White          Speeding
# 2005-01-18 08:15:00          1965.0        40.0       White          Speeding
# 2005-01-23 23:15:00          1972.0        33.0       White          Speeding
# 2005-02-20 17:15:00          1986.0        19.0       White  Call for Service
# 2005-03-14 10:00:00          1984.0        21.0       White          Speeding
#
# ...

# %%
ri['driver_race'].value_counts()
# Out:
# White       62156
# Black       12244
# Hispanic     9507
# Asian        2259
# Other         240
# Name: driver_race, dtype: int64

# %%
#Filtering DataFrame rows
ri.driver_race.value_counts()
ri.stop_outcome.value_counts(normalize=True)
white = ri[ri.driver_race=='White']
white.stop_outcome.value_counts(normalize=True)
# Out:
# Citation            0.903292
# Warning             0.058160
# Arrest Driver       0.023071
# No Action           0.006403
# N/D                 0.006162
# Arrest Passenger    0.002912
# Name: stop_outcome, dtype: float64

# %%
white.stop_outcome.value_counts()
# Out:
# Citation            56145
# Warning              3615
# Arrest Driver        1434
# No Action             398
# N/D                   383
# Arrest Passenger      181
# Name: stop_outcome, dtype: int64
